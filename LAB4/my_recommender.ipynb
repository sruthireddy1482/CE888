# %% [markdown]
# <a href="https://colab.research.google.com/github/sruthireddy1482/CE888/blob/main/LAB4/my_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("https://raw.githubusercontent.com/albanda/CE888/master/lab4-recommender/jester-data-1.csv",header=None)
data.head()
# Out:
#    0      1      2      3      4    ...    96     97     98     99     100
# 0   74  -7.82   8.79  -9.66  -8.16  ...  99.00  -5.63  99.00  99.00  99.00
# 1  100   4.08  -0.29   6.36   4.37  ...  -2.14   3.06   0.34  -4.32   1.07
# 2   49  99.00  99.00  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 3   48  99.00   8.35  99.00  99.00  ...  99.00  99.00  99.00  99.00  99.00
# 4   91   8.50   4.61  -4.17  -5.39  ...   1.55   3.11   6.55   1.80   1.60
#
# [5 rows x 101 columns]

# %%
print(data.shape)
# Out:
# (24983, 101)

# %%
data.describe()
# Out:
#                 0             1    ...           99            100
# count  24983.000000  24983.000000  ...  24983.000000  24983.000000
# mean      72.467478     34.401435  ...     55.753357     60.138090
# std       21.859600     46.707059  ...     49.237139     47.913531
# min       36.000000     -9.950000  ...     -9.950000     -9.950000
# 25%       53.000000     -0.150000  ...      1.335000      3.930000
# 50%       72.000000      5.050000  ...     99.000000     99.000000
# 75%      100.000000     99.000000  ...     99.000000     99.000000
# max      100.000000     99.000000  ...     99.000000     99.000000
#
# [8 rows x 101 columns]

# %%
data.replace(99, np.NaN,inplace=True)
data.head()
# Out:
#      0     1     2     3     4     5    ...   95    96    97    98    99    100
# 0   74.0 -7.82  8.79 -9.66 -8.16 -7.52  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1  100.0  4.08 -0.29  6.36  4.37 -2.38  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2   49.0   NaN   NaN   NaN   NaN  9.03  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3   48.0   NaN  8.35   NaN   NaN  1.80  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4   91.0  8.50  4.61 -4.17 -5.39  1.36  ...  5.73  1.55  3.11  6.55  1.80  1.60
#
# [5 rows x 101 columns]

# %%
data=data.drop(data.columns[[0]], axis = 1)
data
# Out:
#         1     2     3     4     5     6    ...   95    96    97    98    99    100
# 0     -7.82  8.79 -9.66 -8.16 -7.52 -8.50  ...   NaN   NaN -5.63   NaN   NaN   NaN
# 1      4.08 -0.29  6.36  4.37 -2.38 -9.66  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 2       NaN   NaN   NaN   NaN  9.03  9.27  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3       NaN  8.35   NaN   NaN  1.80  8.16  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4      8.50  4.61 -4.17 -5.39  1.36  1.60  ...  5.73  1.55  3.11  6.55  1.80  1.60
# ...     ...   ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...   ...
# 24978  0.44  7.43  9.08  2.33  3.20  6.75  ...  8.45  9.03  6.55  8.69  8.79  7.43
# 24979  9.13 -8.16  8.59  9.08  0.87 -8.93  ...  9.22 -8.20 -7.23 -8.59  9.13  8.45
# 24980   NaN   NaN   NaN   NaN -7.77   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 24981   NaN   NaN   NaN   NaN -9.71   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
train = data.dropna()
train.head()
# Out:
#      1     2     3     4     5     6    ...   95    96    97    98    99    100
# 1   4.08 -0.29  6.36  4.37 -2.38 -9.66  ... -0.19 -2.14  3.06  0.34 -4.32  1.07
# 5  -6.17 -3.54  0.44 -8.50 -7.09 -4.32  ... -2.18 -3.35  0.05 -9.08 -5.05 -3.45
# 7   6.84  3.16  9.17 -6.21 -8.16 -1.70  ... -3.16 -3.35  2.14 -0.05  1.31  0.00
# 8  -3.79 -3.54 -9.42 -6.89 -8.74 -0.29  ... -0.29 -0.29 -0.29 -0.29 -3.40 -4.95
# 11  1.31  1.80  2.57 -2.38  0.73  0.73  ...  3.45  5.44  4.08  2.48  4.51  4.66
#
# [5 rows x 100 columns]

# %%
print(train.shape)
# Out:
# (7200, 100)

# %%
test = data[data.isnull().any(axis=1)]
test.head()
# Out:
#     1     2     3     4     5     6    ...   95    96    97    98   99   100
# 0 -7.82  8.79 -9.66 -8.16 -7.52 -8.50  ...   NaN   NaN -5.63   NaN  NaN  NaN
# 2   NaN   NaN   NaN   NaN  9.03  9.27  ...   NaN   NaN   NaN   NaN  NaN  NaN
# 3   NaN  8.35   NaN   NaN  1.80  8.16  ...   NaN   NaN   NaN   NaN  NaN  NaN
# 4  8.50  4.61 -4.17 -5.39  1.36  1.60  ...  5.73  1.55  3.11  6.55  1.8  1.6
# 6   NaN   NaN   NaN   NaN  8.59 -9.85  ...   NaN  2.33   NaN   NaN  NaN  NaN
#
# [5 rows x 100 columns]

# %%
print(test.shape)
# Out:
# (17783, 100)

# %% [markdown]
# claculating mean of each joke , high mean implies best joke

# %%
avg=train.mean(axis=0)
avg
# Out:
# 1      1.331347
# 2      0.708058
# 3      0.617204
# 4     -1.110300
# 5      0.634107
#          ...
# 96     1.749546
# 97     1.875689
# 98     0.949315
# 99     0.152539
# 100    1.442981
# Length: 100, dtype: float64

# %%
avg.sort_values()
# Out:
# 58   -3.519386
# 16   -2.692678
# 44   -1.763576
# 57   -1.572318
# 74   -1.416282
#         ...
# 32    3.343306
# 27    3.364735
# 36    3.583126
# 89    3.827982
# 50    3.927833
# Length: 100, dtype: float64

# %% [markdown]
# 50th joke is best and 58 th joke is worst

# %%
arr = train.values
print(arr.shape)
# Out:
# (7200, 100)

# %%
rated = np.where(~np.isnan(arr))
print(len(rated[0]), rated[1].shape)
# Out:
# 720000 (720000,)

# %%
def replace(orig, percentage=0.1):
    new_data = orig.copy()
    rated = np.where(~np.isnan(new_data))
    n_rated = len(rated[0])
    idx = np.random.choice(n_rated, size=int(percentage*n_rated), replace=False)
    new_data[rated[0][idx], rated[1][idx]] = 99
    return new_data, (rated[0][idx], rated[1][idx])

# %%
new_arr, idx = replace(arr, 0.1)

# %%
arr[idx[0][0], idx[1][0]]
# Out:
# 6.94

# %%
new_arr[idx[0][0], idx[1][0]]
# Out:
# 99.0

# %% [markdown]
# arr is training set , new arr is validation set

# %%
np.set_printoptions(precision=3)

# %%
new_arr = pd.DataFrame(new_arr)

# %%
arr=pd.DataFrame(arr)

# %%
n_latent_factors = 2

user_ratings = arr.values
# Initialise as random values
latent_user_preferences = np.random.random((user_ratings.shape[0], n_latent_factors))
latent_item_features = np.random.random((user_ratings.shape[1], n_latent_factors))

# %%
latent_item_features
# Out:
# array([[0.136, 0.497],
#        [0.971, 0.975],
#        [0.893, 0.647],
#        [0.751, 0.983],
#        [0.886, 0.901],
#        [0.76 , 0.129],
#        [0.682, 0.442],
#        [0.588, 0.559],
#        [0.653, 0.344],
#        [0.948, 0.476],
#        [0.669, 0.286],
#        [0.535, 0.875],
#        [0.425, 0.236],
#        [0.066, 0.506],
#        [0.203, 0.701],
#        [0.233, 0.074],
#        [0.653, 0.157],
#        [0.323, 0.884],
#        [0.575, 0.554],
#        [0.833, 0.827],
#        [0.574, 0.81 ],
#        [0.872, 0.595],
#        [0.731, 0.839],
#        [0.616, 0.502],
#        [0.622, 0.674],
#        [0.112, 0.456],
#        [0.305, 0.099],
#        [0.35 , 0.846],
#        [0.687, 0.149],
#        [0.042, 0.703],
#        [0.956, 0.56 ],
#        [0.235, 0.831],
#        [0.604, 0.446],
#        [0.653, 0.914],
#        [0.048, 0.853],
#        [0.637, 0.101],
#        [0.256, 0.154],
#        [0.33 , 0.151],
#        [0.794, 0.932],
#        [0.579, 0.39 ],
# ...

# %%
latent_user_preferences
# Out:
# array([[0.063, 0.941],
#        [0.35 , 0.279],
#        [0.088, 0.597],
#        ...,
#        [0.685, 0.027],
#        [0.478, 0.458],
#        [0.647, 0.728]])

# %%
def predict_rating(user_id, item_id):
    """ Predict a rating given a user_id and an item_id.
    """
    user_preference = latent_user_preferences[user_id]
    item_preference = latent_item_features[item_id]
    return user_preference.dot(item_preference)

# %%
def train(user_id, item_id, rating, alpha=0.0001):
    #print(item_id)
    predicted_rating = predict_rating(user_id, item_id)
    err =  predicted_rating - rating
    #print(err)
    user_pref_values = latent_user_preferences[user_id]
    latent_user_preferences[user_id] -= alpha * err * latent_item_features[item_id]
    latent_item_features[item_id] -= alpha * err * user_pref_values
    return err

# %%
def sgd(iterations):
    """ Iterate over all users and all items and train for 
        a certain number of iterations
    """
    mse_history = []
    for iteration in range(iterations):
        error = []
        for user_id in range(latent_user_preferences.shape[0]):
            for item_id in range(latent_item_features.shape[0]):
                rating = user_ratings[user_id, item_id]
                if(not np.isnan(rating) and rating!=99.00):
                    err = train(user_id, item_id, rating)
                    error.append(err)
        mse = (np.array(error) ** 2).mean()   
        if (iteration % 10000) == 0:
            print('Iteration %d/%d:\tMSE=%.6f' % (iteration, iterations, mse))
            mse_history.append(mse)
    return mse_history

# %%
num_iter = 100
hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
plt.figure()
plt.plot(np.arange(0, num_iter, 10), hist)
plt.xlabel("Iterations")
plt.ylabel("MSE")
plt.show()
# Out:
# Iteration 0/100:	MSE=26.700575
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-26017a7bd5fb> in <module>()
#       1 num_iter = 100
# ----> 2 hist = sgd(num_iter)  # Note how the MSE decreases with the number of iterations
#       3 plt.figure()
#       4 plt.plot(np.arange(0, num_iter, 10), hist)
#       5 plt.xlabel("Iterations")
#
# <ipython-input-31-d01b38d5f080> in sgd(iterations)
#      10                 rating = user_ratings[user_id, item_id]
#      11                 if(not np.isnan(rating) and rating!=99.00):
# ---> 12                     err = train(user_id, item_id, rating)
#      13                     error.append(err)
#      14         mse = (np.array(error) ** 2).mean()
#
# <ipython-input-30-cbe3d16a7884> in train(user_id, item_id, rating, alpha)
#       6     user_pref_values = latent_user_preferences[user_id]
# ...

# %%
predictions = latent_user_preferences.dot(latent_item_features.T)
predictions

# %%
values = [zip(user_ratings[i], predictions[i]) for i in range(predictions.shape[0])]
comparison_data = pd.DataFrame(values)
comparison_data.columns = data.columns

# %%
comparison_data
# Out:
#                                1    ...                          100
# 0       (4.08, 0.8558944996384962)  ...   (1.07, 0.9972813158594803)
# 1      (-6.17, 0.3281052888858845)  ...  (-3.45, 0.4461599031047624)
# 2       (6.84, 0.5162345741027811)  ...     (0.0, 0.604959943489154)
# 3      (-3.79, 1.1223755176188028)  ...  (-4.95, 1.4405745084171213)
# 4      (1.31, 0.15339324406368826)  ...   (4.66, 0.2406795614721884)
# ...                            ...  ...                          ...
# 7195   (-2.91, 0.7069773770673132)  ...   (-1.8, 0.8381244336463471)
# 7196    (4.85, 0.8676662458104442)  ...  (-6.36, 1.1739093191361343)
# 7197  (-0.29, 0.36064171480955315)  ...  (-0.68, 0.5800539802760726)
# 7198    (4.17, 0.6479434474541115)  ...    (4.37, 0.861410312368012)
# 7199     (0.44, 0.966577643169112)  ...    (7.43, 1.267488182243232)
#
# [7200 rows x 100 columns]

# %%
movies_data= pd.read_excel('https://github.com/albanda/CE888/raw/master/lab4-recommender/movies_latent_factors.xlsx')
movies_data.head()
# Out:
#    Movie ID  ...  Factor15
# 0        11  ... -0.248806
# 1        12  ...  1.274993
# 2        13  ... -0.419092
# 3        14  ... -0.681191
# 4        22  ... -2.292566
#
# [5 rows x 17 columns]

# %%
comparison_data.iloc[2723:,23:]
# Out:
#                                 24   ...                          100
# 2723  (-4.22, -0.32777833549218865)  ...   (2.86, 1.3812542834225425)
# 2724    (3.3, -0.28810304243179957)  ...   (1.94, 1.2491968679423875)
# 2725   (1.55, -0.18451414623175505)  ...   (8.35, 0.7936217879135945)
# 2726   (0.53, -0.20925769177257714)  ...   (3.93, 0.9285531975965137)
# 2727  (-2.09, -0.22909116425326465)  ...   (-2.72, 0.996397130068276)
# ...                             ...  ...                          ...
# 7195  (-1.89, -0.21184330143132998)  ...   (-1.8, 0.8381244336463471)
# 7196   (-7.14, -0.2751507542645378)  ...  (-6.36, 1.1739093191361343)
# 7197  (-0.29, -0.12397631426281028)  ...  (-0.68, 0.5800539802760726)
# 7198   (-3.2, -0.20388476882130657)  ...    (4.37, 0.861410312368012)
# 7199  (-4.17, -0.30231861453088926)  ...    (7.43, 1.267488182243232)
#
# [4477 rows x 77 columns]

# %%
movies_data.loc[movies_data['Movie ID'] == 604]
# Out:
#     Movie ID                       Title  ...  Factor14  Factor15
# 51       604  The Matrix Reloaded (2003)  ...  0.748458  2.120907
#
# [1 rows x 17 columns]

# %%
movies_data.loc[movies_data['Movie ID'] == 807]
# Out:
#     Movie ID                        Title  ...  Factor14  Factor15
# 64       807  Seven (a.k.a. Se7en) (1995)  ... -0.597342  0.179386
#
# [1 rows x 17 columns]

# %%
movies_data.describe()
# Out:
#            Movie ID       Factor1  ...      Factor14      Factor15
# count    100.000000  1.000000e+02  ...  1.000000e+02  1.000000e+02
# mean    2574.960000  9.658940e-16  ... -2.781109e-16  1.386391e-16
# std     6557.621461  1.434126e+00  ...  8.072468e-01  8.013211e-01
# min       11.000000 -3.063639e+00  ... -2.381119e+00 -2.292566e+00
# 25%      192.250000 -9.085676e-01  ... -4.005383e-01 -4.391575e-01
# 50%      602.500000 -1.074541e-01  ... -1.154223e-02  5.581660e-02
# 75%     1578.250000  1.050603e+00  ...  4.554364e-01  4.736635e-01
# max    36955.000000  4.023815e+00  ...  2.215933e+00  2.120907e+00
#
# [8 rows x 16 columns]
